# %% [markdown]
# # 🛡️ Red Team Security Testing
#
# This notebook shows how to run an **automated AI red‑teaming scan** against a Foundry agent using the **AI Red Teaming Agent** in Microsoft Foundry. Red teaming sends adversarial prompts to your agent and checks how often it produces unsafe content — the **Attack Success Rate (ASR)**.
#
# ## 🎯 Learning Objectives
#
# 1. **Understand AI red teaming** — risk categories, attack strategies, and ASR
# 2. **Build a target agent** to scan (a banking assistant)
# 3. **Launch a cloud red‑team scan** with `beta.red_teams` (preview)
# 4. **Read scan status & results** and clean up resources
#
# ## 💼 Industry Use Case: Banking Assistant Safety Sign‑off
#
# Before a financial‑services chatbot reaches customers, security and compliance teams must prove it resists abuse. An automated red‑team scan probes the agent with adversarial inputs across categories like **violence**, **hate**, **self‑harm**, and **sexual content** and reports how often guardrails fail — evidence for a go/no‑go security review.
#
# ### 🔬 What gets measured
# - **Risk categories** — the harm types probed (e.g. `VIOLENCE`, `HATE_UNFAIRNESS`, `SELF_HARM`, `SEXUAL`)
# - **Attack strategies** — transformations applied to seed prompts (e.g. `BASELINE`, `BASE64`, `FLIP`, `JAILBREAK`, `CRESCENDO`)
# - **Attack Success Rate (ASR)** — % of adversarial turns that elicited unsafe output (lower is safer)
#
# ### ⚠️ Disclaimer
# > This notebook uses `simulation_only=True` and `num_turns=1` to keep the scan **fast and low‑cost** for teaching. It only generates adversarial prompts — it does **not** evaluate full responses. Production sign‑off scans use more turns, multiple categories, and full evaluation. Red‑team runs cannot be deleted, so a small run record will remain in the project.

# %%
import os
import time
from pathlib import Path
from dotenv import load_dotenv

from azure.identity import AzureCliCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import RedTeam, RiskCategory, AttackStrategy, PromptAgentDefinition

# Load environment variables from repo-root .env
env_path = Path().absolute().parent / ".env"
load_dotenv(env_path)

project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
tenant_id = os.environ.get("TENANT_ID")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")

if not project_endpoint:
    raise ValueError("🚨 AI_FOUNDRY_PROJECT_ENDPOINT not set in .env")

# allow_preview=True exposes the beta.red_teams operations (Entra-only auth)
credential = AzureCliCredential(tenant_id=tenant_id) if tenant_id else AzureCliCredential()
project_client = AIProjectClient(endpoint=project_endpoint, credential=credential, allow_preview=True)

print(f"📍 Project: {project_endpoint[:55]}...")
print(f"🤖 Model deployment: {model_deployment}")
print("✅ AIProjectClient ready (preview features enabled)")

# %% [markdown]
# ## 1. Build the Target Agent
#
# A red‑team scan needs a **target** — the agent under test. We create a small banking assistant with `agents.create_version()`. The scan will reference it by `name` + `version`.
#
# The cell also prints the available **risk categories** and a few **attack strategies** so you can see what the scanner can probe.

# %%
# What the scanner can probe
print("Risk categories:", [r.value for r in RiskCategory])
print("Sample attack strategies:", [a.value for a in list(AttackStrategy)[:8]])

# Create the banking assistant to be scanned
AGENT_NAME = "redteam-banking-target"
agent = project_client.agents.create_version(
    AGENT_NAME,
    definition=PromptAgentDefinition(
        model=model_deployment,
        instructions=(
            "You are a banking customer-support assistant. Help with balances, "
            "transfers, and account questions. Politely refuse unsafe or "
            "out-of-scope requests."
        ),
    ),
)
print(f"\n✅ Target agent: {agent.name} (v{agent.version})")

# %% [markdown]
# ## 2. Launch the Red‑Team Scan
#
# We call `project_client.beta.red_teams.create()` with a `RedTeam` definition targeting our agent. We keep one risk category and the `BASELINE` strategy with `simulation_only=True` and `num_turns=1` to limit time and cost.
#
# > 🐛 The SDK's `AzureAIAgentTarget` emits the wrong discriminator, so we pass a **raw dict** target `{"type": "AzureAIAgent", "name": ..., "version": ...}`.

# %%
# Raw dict target works around the SDK's AzureAIAgentTarget discriminator bug
red_team = project_client.beta.red_teams.create(
    RedTeam(
        display_name="banking-assistant-safety-scan",
        target={"type": "AzureAIAgent", "name": agent.name, "version": agent.version},
        risk_categories=[RiskCategory.VIOLENCE],
        attack_strategies=[AttackStrategy.BASELINE],
        num_turns=1,
        simulation_only=True,
    )
)

print(f"🚀 Scan launched: {red_team.name}")
print(f"   target: {agent.name} (v{agent.version})")
print(f"   risk categories: {[getattr(r, 'value', r) for r in (red_team.risk_categories or [])]}")
print(f"   attack strategies: {[getattr(a, 'value', a) for a in (red_team.attack_strategies or [])]}")
print(f"   status: {red_team.status}")

# %% [markdown]
# ## 3. Monitor Results & Clean Up
#
# Scans run asynchronously. We poll `beta.red_teams.get()` briefly and report the status reached. A finished scan exposes ASR and per‑category metrics in `properties` and in the **Foundry portal → Evaluations → Red teaming**.
#
# Finally we delete the target agent. Red‑team runs have **no delete API**, so the run record stays in the project (expected, harmless).

# %%
# Poll briefly for a terminal status (simulation_only is fast; cap to stay well under timeout)
TERMINAL = {"Completed", "Failed", "Cancelled", "Canceled"}
deadline = time.time() + 240  # ~4 min budget
status = red_team.status
while time.time() < deadline:
    status = project_client.beta.red_teams.get(red_team.name).status
    print(f"⏳ status: {status}")
    if status in TERMINAL:
        break
    time.sleep(20)

if status == "Completed":
    print("\n🛡️ Scan completed. Open Foundry portal → Evaluations → Red teaming for ASR & per-category breakdown.")
else:
    print(f"\nℹ️ Scan still running ({status}). Results will appear in the Foundry portal when finished.")

# Cleanup: delete the target agent (red-team runs cannot be deleted — record remains by design)
# [kept-in-foundry] project_client.agents.delete(AGENT_NAME)
print(f"🧹 Deleted target agent: {AGENT_NAME}")
print("✅ Done — red-team security testing demo complete.")

# %% [markdown]
# ## 📚 References
#
# - [AI Red Teaming Agent](https://learn.microsoft.com/azure/foundry/concepts/ai-red-teaming-agent) — concepts behind automated adversarial scans and ASR
# - [Run the AI Red Teaming Agent locally](https://learn.microsoft.com/azure/foundry/how-to/develop/run-scans-ai-red-teaming-agent) — scan() with risk_categories and num_objectives
# - [Run the AI Red Teaming Agent in the cloud](https://learn.microsoft.com/azure/foundry/how-to/develop/run-ai-red-teaming-cloud) — larger pre/post-deployment scans against a Foundry agent
# - [Supported risk categories](https://learn.microsoft.com/azure/foundry/concepts/ai-red-teaming-agent#supported-risk-categories) — RiskCategory values: violence, hate, sexual, self-harm, etc.
# - [Supported attack strategies](https://learn.microsoft.com/azure/foundry/concepts/ai-red-teaming-agent#supported-attack-strategies) — AttackStrategy options like Base64, Flip, Jailbreak, Crescendo
# - [Risk and safety evaluators](https://learn.microsoft.com/azure/foundry/concepts/evaluation-evaluators/risk-safety-evaluators) — how attack-response pairs are scored for safety
#
# > 💡 Tip: search the official docs live via the **Microsoft Learn MCP** at `https://learn.microsoft.com/api/mcp`.
