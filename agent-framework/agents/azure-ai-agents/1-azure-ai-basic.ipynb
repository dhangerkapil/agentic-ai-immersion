# %% [markdown]
# ## 🔐 Prerequisites
#
# Before running the first cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login
# ```
#
# or
#
# ```bash
# az login --use-device-code
# ```

# %% [markdown]
# # 🏦 Azure AI Agent Basic Example 💼
#
# This notebook demonstrates basic usage of `FoundryAgent` for connecting to and using pre-configured Azure AI Foundry agents.
#
# ## Features Covered:
# - Setting up `FoundryAgent` for Azure AI Foundry
# - Creating an advisor workflow with function tools
# - Using function tools for banking operations
# - Streaming and non-streaming responses
# - Proper resource management with async context managers
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **The financial information provided by this notebook is for general educational and demonstration purposes only and is not intended as financial, investment, legal, or tax advice.** Always consult with qualified financial advisors before making any financial decisions.

# %% [markdown]
# ## Prerequisites
#
# Before running this notebook, ensure you have:
#
# 1. **Azure AI Foundry Project**: Access to a Foundry project with a pre-configured agent (PromptAgent or HostedAgent)
# 2. **Authentication**: Azure CLI installed and authenticated (`az login --use-device-code`)
# 3. **Environment Variables**: Set up your `.env` file with connection details:
#    - `FOUNDRY_PROJECT_ENDPOINT` (preferred) or `AI_FOUNDRY_PROJECT_ENDPOINT`
#    - `AGENT_NAME` (optional, defaults to `FinancialAdvisorAgent`)
# 4. **Dependencies**: Required agent-framework packages installed (including `agent-framework-foundry`)
#
# If you need to use a different tenant, specify the tenant ID:
# ```bash
# az login --tenant <tenant-id>
# ```

# %% [markdown]
# ## Import Required Libraries
#
# First, let's import the necessary libraries. We use `FoundryAgent` to connect to a pre-configured agent in Azure AI Foundry:

# %%
# Copyright (c) Microsoft. All rights reserved.

from random import randint, uniform
from typing import Annotated, Any, Mapping, Sequence

from agent_framework._tools import FunctionInvocationLayer
from agent_framework._middleware import ChatMiddlewareLayer
from agent_framework._types import Message
from agent_framework.foundry import FoundryAgent, RawFoundryAgentChatClient
from agent_framework.observability import ChatTelemetryLayer
from azure.identity import AzureCliCredential
from pydantic import Field


class FoundryAgentChatClient(
    FunctionInvocationLayer,
    ChatMiddlewareLayer,
    ChatTelemetryLayer,
    RawFoundryAgentChatClient,
):
    """Workaround for rc6: strip tool schemas from API request.

    Foundry agents have tools configured server-side, so sending tool
    schemas in the request causes a 400 error. But the local function
    implementations are still needed for FunctionInvocationLayer to
    execute function calls returned by the agent.
    """

    async def _prepare_options(
        self,
        messages: Sequence[Message],
        options: Mapping[str, Any],
        **kwargs: Any,
    ) -> dict[str, Any]:
        run_options = await super()._prepare_options(messages, options, **kwargs)
        run_options.pop("tools", None)
        run_options.pop("tool_choice", None)
        run_options.pop("parallel_tool_calls", None)
        return run_options

# %% [markdown]
# ## Initial Setup
#
# Load environment variables from the `.env` file for Azure AI Project configuration:

# %%
from pathlib import Path
import os
from dotenv import load_dotenv

# Load environment variables from .env file (two directories up)
notebook_path = Path().absolute()
load_dotenv('../../.env')

# Verify environment setup
endpoint = os.getenv('AI_FOUNDRY_PROJECT_ENDPOINT')
model = os.getenv('AZURE_AI_MODEL_DEPLOYMENT_NAME')

print("🔧 Environment Configuration:")
print(f"✅ Project Endpoint: {endpoint[:50]}..." if endpoint else "❌ AI_FOUNDRY_PROJECT_ENDPOINT not set")
print(f"✅ Model Deployment: {model}" if model else "❌ AZURE_AI_MODEL_DEPLOYMENT_NAME not set")
# Out:
# 🔧 Environment Configuration:
# ✅ Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api...
# ✅ Model Deployment: gpt-4o

# %% [markdown]
# ## Define Function Tools 🏦
#
# Function tools allow the agent to call specific functions to gather information or perform operations. Here we define functions for account balance and loan rate inquiries:

# %%
def get_account_balance(
    account_id: Annotated[str, Field(description="The customer account ID to check balance for.")],
) -> str:
    """Get the current balance for a customer account."""
    # Simulated account balances for demo
    balances = {
        "checking": round(uniform(1000, 15000), 2),
        "savings": round(uniform(5000, 50000), 2),
        "investment": round(uniform(10000, 100000), 2)
    }
    account_type = ["checking", "savings", "investment"][randint(0, 2)]
    return f"Account {account_id} ({account_type}): Current balance is ${balances[account_type]:,.2f}"


def get_loan_rates(
    loan_type: Annotated[str, Field(description="Type of loan: mortgage, auto, personal, or business")],
) -> str:
    """Get current interest rates for different loan types."""
    rates = {
        "mortgage": {"rate": 6.5, "term": "30 years", "min_credit": 620},
        "auto": {"rate": 7.2, "term": "5 years", "min_credit": 600},
        "personal": {"rate": 10.5, "term": "3 years", "min_credit": 650},
        "business": {"rate": 8.0, "term": "10 years", "min_credit": 680}
    }
    loan_type = loan_type.lower()
    if loan_type in rates:
        r = rates[loan_type]
        return f"Current {loan_type} loan rates: {r['rate']}% APR, {r['term']} term, minimum credit score: {r['min_credit']}"
    return f"Unknown loan type: {loan_type}. Available types: mortgage, auto, personal, business"


# Financial disclaimer constant
FINANCIAL_DISCLAIMER = """
⚠️ DISCLAIMER: This information is for educational purposes only and does not constitute 
financial advice. Please consult with a qualified financial advisor for personalized guidance.
"""

# %% [markdown]
# ## Non-Streaming Response Example 💰
#
# In this example, we'll connect to a pre-configured Foundry agent and get a complete response at once (non-streaming):
#
# - `FoundryAgent(project_endpoint=..., agent_name=..., credential=...)` is the recommended API
# - This replaces the older `AzureAIProjectAgentProvider` / `create_agent()` pattern

# %%
async def non_streaming_example() -> None:
    """Example of non-streaming response (get the complete result at once)."""
    print("=== 🏦 Non-streaming Response Example ===")

    agent = FoundryAgent(
        agent_name="FinancialAdvisorAgent",
        project_endpoint=endpoint,
        credential=AzureCliCredential(),
        instructions="""You are a helpful Financial Services Advisor for a retail bank.
        You can help customers check account balances and inquire about loan rates.
        Always be professional and provide clear, helpful information.""",
        tools=[get_account_balance, get_loan_rates],
        client_type=FoundryAgentChatClient,
    )

    query = "What are the current mortgage loan rates?"
    print(f"🤔 Customer: {query}")
    result = await agent.run(query)
    print(f"🏦 Advisor: {result.text}")
    print(FINANCIAL_DISCLAIMER)

# %% [markdown]
# ## Streaming Response Example 📊
#
# In this example, we'll demonstrate streaming responses by calling `agent.run(query, stream=True)` and iterating updates as they arrive:

# %%
async def streaming_example() -> None:
    """Example of streaming response (get results as they are generated)."""
    print("=== 📊 Streaming Response Example ===")

    agent = FoundryAgent(
        agent_name="FinancialAdvisorAgent",
        project_endpoint=endpoint,
        credential=AzureCliCredential(),
        instructions="""You are a helpful Financial Services Advisor for a retail bank.
        You can help customers check account balances and inquire about loan rates.
        Always be professional and provide clear, helpful information.""",
        tools=[get_account_balance, get_loan_rates],
        client_type=FoundryAgentChatClient,
    )

    query = "Can you check the balance for account ACC-12345 and also tell me about auto loan rates?"
    print(f"🤔 Customer: {query}")
    print("🏦 Advisor: ", end="", flush=True)
    async for chunk in agent.run(query, stream=True):
        if chunk.text:
            print(chunk.text, end="", flush=True)
    print("\n")
    print(FINANCIAL_DISCLAIMER)

# %% [markdown]
# ## Main Execution Function
#
# This function orchestrates the execution of both examples:

# %%
async def main() -> None:
    print("=== 🏦 Azure AI Agent Example ===\n")
    
    await non_streaming_example()
    print("\n" + "="*60 + "\n")
    await streaming_example()

# %% [markdown]
# ## Run the Examples 🚀
#
# Execute the main function to run both streaming and non-streaming Financial Advisor examples:

# %%
# Run the main function
await main()
# Out:
# === 🏦 Azure AI Agent Example ===
#
# === 🏦 Non-streaming Response Example ===
# 🤔 Customer: What are the current mortgage loan rates?
# 🏦 Advisor: The current mortgage loan rates are as follows:
#
# - **Interest Rate (APR):** 6.5%
# - **Loan Term:** 30 years
# - **Minimum Credit Score Required:** 620
#
# If you have any additional questions or need assistance, feel free to ask!
#
# ⚠️ DISCLAIMER: This information is for educational purposes only and does not constitute
# financial advice. Please consult with a qualified financial advisor for personalized guidance.
#
#
# ============================================================
#
# === 📊 Streaming Response Example ===
# 🤔 Customer: Can you check the balance for account ACC-12345 and also tell me about auto loan rates?
# 🏦 Advisor: Here’s the information you requested:
#
# 1. **Account Balance**: The current balance for account **ACC-12345** is **$11,120.45**.
#
# 2. **Auto Loan Rates**:
#    - Interest Rate (APR): **7.2%**
#    - Loan Term: **5 years**
#    - Minimum Credit Score: **600**
#
# Let me know if you need additional assistance!
#
#
# ⚠️ DISCLAIMER: This information is for educational purposes only and does not constitute
# financial advice. Please consult with a qualified financial advisor for personalized guidance.

# %% [markdown]
# ## Key Takeaways 📚
#
# ### Key Concepts
#
# 1. **FoundryAgent Pattern**: Use `FoundryAgent(agent_name=..., project_endpoint=..., credential=AzureCliCredential())` to connect to pre-configured agents in Azure AI Foundry
# 2. **Simple Credential**: Use sync `AzureCliCredential()` directly — no `async with` context manager needed
# 3. **Tooling Model**: For pre-configured Foundry agents, tools are configured on the agent in Foundry (not passed per request)
# 4. **Response Types**:
#    - Non-streaming: `result = await agent.run("query")` → `result.text`
#    - Streaming: `async for chunk in agent.run("query", stream=True): print(chunk.text)`
# 5. **Use Cases**: Applications like balance inquiries and loan-rate checks
#
# ### Migration Notes
#
# - `AzureAIProjectAgentProvider`, `AzureAIClient`, and `AzureAIAgentClient` are deprecated for this flow
# - `FoundryAgent` replaces the old `create_agent()`-style pattern for pre-configured Foundry agents
# - `RawFoundryAgentChatClient` remains the low-level extension point for advanced customization
