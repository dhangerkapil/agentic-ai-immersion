# %% [markdown]
# ## 🔐 Prerequisites
#
# Before running the first cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login
# ```
#
# or
#
# ```bash
# az login --use-device-code
# ```

# %% [markdown]
# # 📈 Azure AI Agent with Bing Grounding - Financial Market Research 🏦
#
# This notebook demonstrates how to create an Azure AI agent using **Bing Grounding** for real-time market research. Since `BingGroundingTool` is a hosted tool, it must be configured server-side on the Foundry agent — we use the `azure-ai-projects` SDK to create the agent, then `FoundryAgent` from the Agent Framework to run it.
#
# ## Features Covered:
# - Creating a Foundry agent with `BingGroundingTool` via `AIProjectClient`
# - Connecting to the agent with `FoundryAgent` from the Agent Framework
# - Real-time financial market research using Bing search
# - Proper resource cleanup
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **Financial information retrieved from web searches is for informational purposes only. Always verify with official sources and consult qualified financial advisors before making investment decisions.**

# %% [markdown]
# ## Prerequisites
#
# Before running this notebook, ensure you have:
# 1. **Azure CLI**: Installed and authenticated (`az login --use-device-code`)
# 2. **Microsoft Foundry project**: With deployed models
# 3. **Bing Connection**: Bing Grounding connection provisioned in your Foundry project
# 4. **Environment Variables**: Set up your `.env` file with:
#    - `AI_FOUNDRY_PROJECT_ENDPOINT`
#    - `AZURE_AI_MODEL_DEPLOYMENT_NAME`
#    - `GROUNDING_WITH_BING_CONNECTION_NAME`

# %% [markdown]
# ## Import Libraries
#
# Import the Agent Framework (`FoundryAgent`) and Azure AI Projects SDK (for creating the Bing-grounded agent server-side):

# %%
import os
from pathlib import Path

# Agent Framework imports
from agent_framework.foundry import FoundryAgent

# Azure SDK imports for creating the Bing-grounded agent server-side
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    PromptAgentDefinition,
    BingGroundingTool,
    BingGroundingSearchToolParameters,
    BingGroundingSearchConfiguration,
)
from azure.identity import AzureCliCredential

# %% [markdown]
# ## Initial Setup
#
# Load environment variables from the `.env` file:

# %%
from dotenv import load_dotenv

# Load environment variables from .env file (two directories up)
load_dotenv('../../.env')

# Verify environment setup
endpoint = os.getenv('AI_FOUNDRY_PROJECT_ENDPOINT')
model = os.getenv('AZURE_AI_MODEL_DEPLOYMENT_NAME')
bing_conn_name = os.getenv('GROUNDING_WITH_BING_CONNECTION_NAME')

print("🔧 Environment Configuration:")
print(f"✅ Project Endpoint: {endpoint[:50]}..." if endpoint else "❌ AI_FOUNDRY_PROJECT_ENDPOINT not set")
print(f"✅ Model Deployment: {model}" if model else "❌ AZURE_AI_MODEL_DEPLOYMENT_NAME not set")
print(f"✅ Bing Connection: {bing_conn_name}" if bing_conn_name else "❌ GROUNDING_WITH_BING_CONNECTION_NAME not set")
# Out:
# 🔧 Environment Configuration:
# ✅ Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api...
# ✅ Model Deployment: gpt-4o
# ✅ Bing Connection: foundrysearch

# %% [markdown]
# ## Create Bing-Grounded Agent in Foundry 🔍
#
# Use `AIProjectClient` to create a server-side agent with `BingGroundingTool`. This agent will be accessible by name via `FoundryAgent`:

# %%
credential = AzureCliCredential()

# Initialize AIProjectClient to create agent with Bing grounding
project_client = AIProjectClient(
    endpoint=endpoint,
    credential=credential,
)

# Get Bing connection ID from the Foundry project
bing_connection = project_client.connections.get(name=bing_conn_name)
conn_id = bing_connection.id
print(f"🔗 Bing Connection ID: {conn_id}")

# Create BingGroundingTool
bing_tool = BingGroundingTool(
    bing_grounding=BingGroundingSearchToolParameters(
        search_configurations=[
            BingGroundingSearchConfiguration(
                project_connection_id=conn_id
            )
        ]
    )
)

# Create the agent server-side with Bing grounding
AGENT_NAME = "financial-market-research-agent"

bing_agent = project_client.agents.create_version(
    agent_name=AGENT_NAME,
    definition=PromptAgentDefinition(
        model=model,
        instructions=(
            "You are a Financial Market Research Analyst with Bing search capabilities. "
            "Always: 1) Use Bing to find current interest rates, market news, and economic trends. "
            "2) Cite your sources and include relevant dates. "
            "3) Remind users that past performance doesn't guarantee future results. "
            "4) Provide disclaimers that this is not investment advice."
        ),
        tools=[bing_tool],
    ),
)

print(f"✅ Created Foundry agent: {bing_agent.name} (version: {bing_agent.version})")
# Out:
# 🔗 Bing Connection ID: /subscriptions/93c5449c-bbb2-4249-9461-ddf749e03430/resourceGroups/demoaifoundry/providers/Microsoft.CognitiveServices/accounts/demopocaifoundry/projects/demoproject/connections/foundrysearch
# ✅ Created Foundry agent: financial-market-research-agent (version: 2)

# %% [markdown]
# ## Connect with FoundryAgent and Run Queries 📈
#
# Now use `FoundryAgent` from the Agent Framework to connect to the Bing-grounded agent and run market research queries:

# %%
async def main() -> None:
    """Use FoundryAgent to connect to the Bing-grounded agent for market research."""
    
    # Connect to the server-side agent via FoundryAgent
    agent = FoundryAgent(
        agent_name=AGENT_NAME,
        project_endpoint=endpoint,
        credential=credential,
    )
    
    print("=== 📈 Azure AI Financial Market Research Agent (Bing Grounding) ===\n")
    
    # Market research query
    user_input = "What are the latest trends in the banking and financial services sector?"
    print(f"🤔 Analyst Query: {user_input}")
    response = await agent.run(user_input)
    print(f"📊 Market Research: {response.text}\n")
    print("⚠️ Disclaimer: This information is for research purposes only. Consult a financial advisor for investment decisions.")

# %% [markdown]
# ## Execute the Example 🚀
#
# Run the main function to see the Financial Market Research agent in action:

# %%
# Run the main function
await main()
# Out:
# === 📈 Azure AI Financial Market Research Agent (Bing Grounding) ===
#
# 🤔 Analyst Query: What are the latest trends in the banking and financial services sector?
# 📊 Market Research: The banking and financial services sector in 2026 is being shaped by several transformative trends:
#
# 1. **AI-Driven Transformation**: Artificial Intelligence is central to hyper-personalized customer experiences, automating tasks like compliance checks, personal finance management, and customer support through AI agents and advanced chatbots【4:0†source】【4:2†source】【4:4†source】.
#
# 2. **Digital Currencies and Smart Money**: Stablecoins, central bank digital currencies (CBDCs), and tokenized assets are moving into the mainstream, reshaping payment systems and forcing banks to adapt. Smarter payment solutions and programmable money are empowering transactions to become more seamless and efficient【4:1†source】【4:4†source】.
#
# 3. **Emphasis on Customer Experience**: Banks focus on creating conversational and adaptive experiences using predictive analytics and AI. This ensures seamless engagement across customer touchpoints to enhance loyalty and satisfaction【4:0†source】【4:1†source】.
#
# 4. **Consolidation and Mergers**: After significant merger activity in 2025, 2026 is expected to see even more consolidations among banks, with larger institutions acquiring smaller ones. Increased de novo bank applications have also been reported【4:3†source】.
#
# 5. **Regulatory Shifts**: Post-2025 deregulation is seeing a shift towards real-time and embedded regulations aimed at risk mitigation while embracing innovations like digital assets【4:3†source】【4:4†source】.
#
# 6. **Increased Focus on Environmental, Social, and Governance (ESG) Frameworks**: ESG considerations are becoming integral as financial institutions align with global sustainability and compliance expectations【4:2†source】.
#
# 7. **Technology-Driven Changes**: Quantum computing, enhanced digital infrastructures, and AI-ready data are being emphasized to drive innovation and operational efficiency【4:0†source】【4:4†source】.
#
# 8. **Adapting to Macroeconomic Challenges**: Ongoing macroeconomic uncertainty, inflation, and competitive pressures from non-bank entities are pushing banks to diversify revenue streams and develop stronger strategies【4:4†source】.
#
# These trends highlight the sector's ongoing evolution towards embracing digital advancements, customer-centric business models, and regulatory adaptations to meet global demands.
#
# _Disclaimer: This is not financial advice. Please consult a professional for decisions related to investments or financial planning._
#
# ⚠️ Disclaimer: This information is for research purposes only. Consult a financial advisor for investment decisions.

# %% [markdown]
# ## Try Additional Market Research Queries 📊
#
# Let's test the agent with more financial market research queries:

# %%
async def financial_market_research_queries():
    """Test the agent with multiple market research queries."""
    
    agent = FoundryAgent(
        agent_name=AGENT_NAME,
        project_endpoint=endpoint,
        credential=credential,
    )
    
    queries = [
        "What are the current Federal Reserve interest rate expectations?",
        "What are the latest news about major bank earnings and financial sector performance?",
        "What is the current state of the mortgage market and housing finance trends?",
        "What are the emerging trends in fintech and digital banking?"
    ]
    
    for query in queries:
        print(f"\n{'='*60}")
        print(f"🔍 Research Query: {query}")
        print("-"*40)
        response = await agent.run(query)
        print(f"📊 Analysis: {response.text}")
        print("⚠️ For informational purposes only. Verify with official sources.")

# Run financial market research queries
await financial_market_research_queries()
# Out:
# ============================================================
# 🔍 Research Query: What are the current Federal Reserve interest rate expectations?
# ----------------------------------------
# 📊 Analysis: As of April 2026, the Federal Reserve has held the federal funds rate steady at a target range of 3.50%-3.75% following a phase of rate cuts since late 2024. Markets now widely expect the rate to remain at current levels at least through mid-2026. However, future cuts might start as early as September or November, depending on economic data, especially inflation. Current projections indicate a high likelihood of one additional 25-basis-point rate cut in 2026【4:0†source】【4:1†source】【4:4†source】.
#
# Although inflation shows signs of moderation (now at 2.6%), the Fed is remaining cautious, noting that core inflation is still above its 2% target. Policymakers are split, with some arguing to hold rates and others supporting cuts if inflation eases further【4:0†source】【4:2†source】【4:3†source】.
#
# Please note that this information is based on market data and Federal Reserve communication as of April 2026 and is not financial advice. Always consult with a licensed financial advisor before making investment decisions.
# ⚠️ For informational purposes only. Verify with official sources.
#
# ============================================================
# 🔍 Research Query: What are the latest news about major bank earnings and financial sector performance?
# ----------------------------------------
# 📊 Analysis: Here is the latest information on major bank earnings and the financial sector's performance as of now:
#
# 1. **JPMorgan Chase:** The bank plans to release its Q1 2026 earnings on April 14, 2026. Earlier performance updates revealed strong profit reports for Q4 2025, and the bank continues to focus on consumer and community banking, wealth management, and investments【4:4†source】.
#
# 2. **Bank of America:** As of April 2, 2026, their stock price was reported at $49.38. Recent quarterly earnings reports showed steady performance with detailed breakdowns of financial highlights【4:2†source】.
#
# 3. **Broader Financial Sector Performance:** According to the FDIC's Quarterly Banking Profile, FDIC-insured institutions reported a decrease in net income by $1.6 billion in Q4 2025 compared to the previous quarter, despite a strong annual gain of 10.2% in net income for the year【4:1†source】.
#
# NOTE: Market trends and earnings reports are subject to updates. Financial news should be reviewed periodically, and this information is not professional financial advice. Always consult with a financial advisor for investing decisions.
# ⚠️ For informational purposes only. Verify with official sources.
#
# ============================================================
# 🔍 Research Query: What is the current state of the mortgage market and housing finance trends?
# ----------------------------------------
# 📊 Analysis: As of April 2026, the U.S. mortgage market is characterized by rising interest rates and evolving housing finance conditions:
#
# 1. **Mortgage Rates:** The average rate for a 30-year fixed-rate mortgage currently stands at 6.356%, while 15-year fixed-rate mortgages average 5.7%. Elevated rates are leading to reduced mortgage applications, which declined 0.8% in early April. Economic uncertainty, including inflation and Federal Reserve policies, contributes to these rising rates【4:0†source】【4:1†source】.
#
# 2. **Affordability and Home Prices:** Affordability improved in early 2026 when mortgage rates bottomed at 5.95%, but recent rate increases have reduced buyer purchasing power by around 4%. Despite this, many markets remain more affordable compared to last year, and housing inventories are recovering but remain below pre-pandemic levels【4:1†source】.
#
# 3. **Market Dynamics:** The market is influenced by economic factors, including inflation, labor market conditions, and Federal Reserve policy decisions. Inventory levels saw an 8% year-over-year increase, though active listings remain below pre-pandemic norms. Regional variations persist, with the Northeast and Midwest showing strength in home prices, in contrast to softness in some Western markets【4:1†source】【4:2†source】.
#
# 4. **Federal Reserve's Role:** The Federal Reserve's interest rate policies remain steady, with the current target rate between 3.50% and 3.75%. Their restraint on rate cuts impacts borrowing costs, sustaining higher mortgage rates【4:2†source】.
#
# While opportunities exist for certain buyers as inventory slowly improves, the rising rates require careful financial planning. It’s advisable to stay informed and consult financial advisors to navigate the changing market effectively.
#
# *Disclaimer: This information is for educational purposes only and not financial advice.*
# ⚠️ For informational purposes only. Verify with official sources.
#
# ============================================================
# 🔍 Research Query: What are the emerging trends in fintech and digital banking?
# ----------------------------------------
# 📊 Analysis: Here are some of the prominent emerging trends in fintech and digital banking for 2026:
#
# 1. **Artificial Intelligence (AI) and Machine Learning**:
#    - Advanced AI agents and machine learning models are transforming various aspects of fintech, including risk management, personalization, fraud detection, and automating complex tasks like financial reconciliation and compliance monitoring【4:0†source】【4:3†source】.
#    - AI-powered hyper-personalization is redefining customer experiences by enabling predictive analytics for proactive service delivery (e.g., tailored financial advice, automated investment strategies)【4:4†source】.
#
# 2. **Embedded Finance and Banking-as-a-Service (BaaS)**:
#    - Financial services are increasingly being integrated into non-financial platforms, enabling seamless access to transactions through APIs. This evolution transforms banks from product providers to platform enablers【4:2†source】【4:4†source】.
#
# 3. **Tokenization and Digital Currencies**:
#    - The adoption of tokenized assets and the mainstreaming of stablecoins and central bank digital currencies (CBDCs) are reengineering how money is stored, transferred, and utilized【4:1†source】【4:3†source】.
#    - Smarter financial transactions are predicted, leveraging programmable and agentic forms of money that can autonomously execute actions like optimizing liquidity【4:3†source】.
#
# 4. **Quantum and Advanced Technologies**:
#    - Quantum computing is moving into practical applications, particularly in financial modeling, risk assessment, and secure transactions, providing increased computational power for complex tasks【4:4†source】.
#
# 5. **The Shift to Hyper-Automation**:
#    - Banks are employing hyper-automation that combines AI, machine learning, and robotic process automation (RPA) to automate traditionally manual banking processes like credit approvals and risk assessments【4:2†source】【4:3†source】.
#
# 6. **RegTech and Compliance**:
#    - AI-driven solutions are improving the scalability of compliance frameworks, enabling businesses to meet growing regulatory complexity and mitigate risks with operational excellence【4:3†source】.
#
# 7. **People-Centric Digital Banking**:
#    - Banks are emphasizing customer experience (CX) with adaptive, AI-powered personalization, real-time fraud prevention systems, and conversational interfaces using technologies like voice and biometrics【4:0†source】【4:4†source】.
#
# These trends indicate a paradigm shift in fintech and digital banking, fostering smarter, more efficient systems tailored to customer needs. However, financial regulation, technological expertise gaps, and user data protection will remain important challenges for industry players to address.
#
# _Disclaimer: This response is for informational purposes only and should not be considered financial advice. For personal financial matters, consulting with a licensed professional is recommended._
# ⚠️ For informational purposes only. Verify with official sources.

# %% [markdown]
# ## Cleanup 🧹
#
# Optionally delete the server-side agent when done:

# %%
# Uncomment to delete the agent when done
# project_client.agents.delete_version(agent_name=bing_agent.name, agent_version=bing_agent.version)
# print(f"🗑️ Deleted agent: {bing_agent.name} (version: {bing_agent.version})")

# %% [markdown]
# ## Key Takeaways 📚
#
# ### Architecture: Two-Step Approach
#
# Bing grounding is a **hosted tool** that must be configured server-side. The workflow is:
#
# 1. **Create the agent server-side** using `AIProjectClient` with `BingGroundingTool`
# 2. **Connect to it** using `FoundryAgent(agent_name=...)` from the Agent Framework
#
# ```python
# # Step 1: Create agent with Bing grounding (azure-ai-projects SDK)
# bing_tool = BingGroundingTool(
#     bing_grounding=BingGroundingSearchToolParameters(
#         search_configurations=[
#             BingGroundingSearchConfiguration(project_connection_id=conn_id)
#         ]
#     )
# )
# agent_def = project_client.agents.create_version(
#     agent_name="my-agent",
#     definition=PromptAgentDefinition(model=model, tools=[bing_tool], instructions="...")
# )
#
# # Step 2: Run with Agent Framework
# agent = FoundryAgent(agent_name="my-agent", project_endpoint=endpoint, credential=credential)
# result = await agent.run("query")
# ```
#
# ### Why Not `FoundryChatClient` + `Agent`?
#
# | Tool Type | Where to configure | API |
# |---|---|---|
# | `FunctionTool` (local functions) | In code via `tools=[...]` | `FoundryChatClient` + `Agent` |
# | `BingGroundingTool` (hosted) | Server-side on Foundry agent | `FoundryAgent` |
# | `FileSearchTool` (hosted) | Server-side + `get_file_search_tool()` | `FoundryChatClient` + `Agent` |
# | `WebSearchTool` (Responses API) | In code via `get_web_search_tool()` | `FoundryChatClient` + `Agent` |
#
# ### Best Practices
#
# 1. **Source Citation**: Always ask the agent to cite its sources
# 2. **Cleanup**: Delete server-side agents when no longer needed
# 3. **Connection Setup**: Bing connection must be provisioned in the Foundry portal first
# 4. **Disclaimers**: Always include appropriate financial disclaimers
#
# ⚠️ **Disclaimer**: Web search results provide general information and should not be considered professional advice.
